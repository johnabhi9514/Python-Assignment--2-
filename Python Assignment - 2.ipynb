# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=5;
for i in range(n):
    for j in range(i):
        print ('* ', end="")
    print(' ')

for i in range(n,0,-1):
    for j in range(i):
        print('* ', end="")
    print('')
# Out:
#
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ## Q2. 2. Write a Python program to reverse a word after accepting the input from the user.
# Input word: ineuron
# Output: norueni

# %%
name= input("Please enter any word to reverse it")
print(name[::-1])
# Out:
# Please enter any word to reverse itineuron
# norueni
